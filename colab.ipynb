# %%
pwd
# Out:
# '/content'

# %%
# Out:
# bash: run_scripts/discrete/run_d.sh: No such file or directory

# %%
import os

# Check current working directory
print("Current directory:", os.getcwd())

# List contents to verify the path exists
print("\nDirectory contents:")
os.system("ls -la run_scripts/discrete/")

# Or try running with correct path
os.system("bash run_scripts/discrete/run_d.sh")
# Out:
# Current directory: /content
#
# Directory contents:
# 32512
